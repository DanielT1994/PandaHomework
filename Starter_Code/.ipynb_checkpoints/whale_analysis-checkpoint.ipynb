# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale = pd.read_csv("Resources/whale_returns.csv")
whale
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
# Count nulls
whale.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale = whale.dropna()
whale.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo = pd.read_csv("Resources/algo_returns.csv")
algo
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
# Count nulls
algo.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo = algo.dropna(axis = 0, how = 'any')
algo.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp = pd.read_csv('Resources/sp500_history.csv', parse_dates = True, infer_datetime_format = True)
sp
# Out:
#            Date     Close
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %%
# Check Data Types
sp.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
sp = sp.dropna(axis = 0, how = 'any')
sp.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
# Fix Data Types
sp["Close"] = sp["Close"].astype(str)
sp["Close"] = sp["Close"].str.replace("$", "")
sp["Close"] = sp["Close"].astype(float)
sp['Date'] = pd.to_datetime(sp['Date']).dt.date
sp = sp[::-1]
sp.dtypes
# Out:
# C:\Users\PC\anaconda3\envs\pyvizend\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Date      object
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp['SP500 Returns'] = sp['Close'].astype(float).pct_change()
sp = sp.drop(columns = "Close")
sp
# Out:
#             Date  SP500 Returns
# 1648  2012-10-01            NaN
# 1647  2012-10-02       0.000872
# 1646  2012-10-03       0.003624
# 1645  2012-10-04       0.007174
# 1644  2012-10-05      -0.000322
# ...          ...            ...
# 4     2019-04-16       0.000509
# 3     2019-04-17      -0.002274
# 2     2019-04-18       0.001579
# 1     2019-04-22       0.001012
# 0     2019-04-23       0.008841
#
# [1649 rows x 2 columns]

# %%
# Drop nulls
sp.isnull().sum()
sp.dropna()
sp
# Out:
#             Date  SP500 Returns
# 1648  2012-10-01            NaN
# 1647  2012-10-02       0.000872
# 1646  2012-10-03       0.003624
# 1645  2012-10-04       0.007174
# 1644  2012-10-05      -0.000322
# ...          ...            ...
# 4     2019-04-16       0.000509
# 3     2019-04-17      -0.002274
# 2     2019-04-18       0.001579
# 1     2019-04-22       0.001012
# 0     2019-04-23       0.008841
#
# [1649 rows x 2 columns]

# %%
sp = sp.reindex(index=sp.index[::-1])
sp.dropna(axis = 0, how = 'any', inplace = True)
sp
# Out:
#             Date  SP500 Returns
# 0     2019-04-23       0.008841
# 1     2019-04-22       0.001012
# 2     2019-04-18       0.001579
# 3     2019-04-17      -0.002274
# 4     2019-04-16       0.000509
# ...          ...            ...
# 1643  2012-10-08      -0.003457
# 1644  2012-10-05      -0.000322
# 1645  2012-10-04       0.007174
# 1646  2012-10-03       0.003624
# 1647  2012-10-02       0.000872
#
# [1648 rows x 2 columns]

# %%
sp.isnull().sum()
sp.dtypes
# Out:
# Date              object
# SP500 Returns    float64
# dtype: object

# %%
# Rename `Close` Column to be specific to this portfolio.
sp.set_index("Date",inplace = True)
sp
# Out:
#             SP500 Returns
# Date
# 2019-04-23       0.008841
# 2019-04-22       0.001012
# 2019-04-18       0.001579
# 2019-04-17      -0.002274
# 2019-04-16       0.000509
# ...                   ...
# 2012-10-08      -0.003457
# 2012-10-05      -0.000322
# 2012-10-04       0.007174
# 2012-10-03       0.003624
# 2012-10-02       0.000872
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
whale
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# 5     2015-03-09                   0.000582            0.004225
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# ...

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
merge = algo.merge(whale)
merged = pd.concat((merge,sp), join = "outer")
merged['SP500 Returns'] = merged['SP500 Returns'].shift(-1059)
merged.dropna(inplace = True)
merged.set_index("Date", inplace = True)
merged
# Out:
#               Algo 1    Algo 2  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03 -0.001942 -0.000949                  -0.001266           -0.004981
# 2015-03-04 -0.008589  0.002416                   0.002230            0.003241
# 2015-03-05 -0.000955  0.004323                   0.004016            0.004076
# 2015-03-06 -0.004957 -0.011460                  -0.007905           -0.003574
# 2015-03-09 -0.005447  0.001303                   0.000582            0.004225
# ...              ...       ...                        ...                 ...
# 2019-04-25  0.000682 -0.007247                  -0.000285           -0.001291
# 2019-04-26  0.002981  0.005256                   0.008149            0.009162
# 2019-04-29  0.005208  0.002829                   0.001254            0.002719
# 2019-04-30 -0.002944 -0.001570                  -0.001295           -0.002211
# 2019-05-01  0.000094 -0.007358                  -0.005847           -0.001341
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
merged.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cr_merged = (1 + merged).cumprod() - 1
#Plot cumulative returns
cr_merged.plot(figsize = (25,20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
import matplotlib.pyplot as plt
# Box plot to visually show risk
volatility_merged = merged.std() * np.sqrt(252)
volatility_sp = sp.std() * np.sqrt(252)
volatility_whale = whale.std() * np.sqrt(252)
volatility_algo = algo.std() * np.sqrt(252)
volatility_merged.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
volatility_algo.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
volatility_whale.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
volatility_sp.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
std_algo = algo.std()
std_whale = whale.std() 
std_sp = sp.std()
print (std_algo,std_whale,std_sp)
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64 SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64 SP500 Returns    0.008111
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
print (std_sp)
# Determine which portfolios are riskier than the S&P 500
#All but PAULSON & CO.INC. & SOROS FUND MANAGEMENT LLC
# Out:
# SP500 Returns    0.008111
# dtype: float64

# %% [markdown]
# #why doesnt this work?
#
# std_all = {"algo":std_algo, "whale":std_whale, "SP500": std_sp}
# risk = std_sp
# riskier_port = []
# for x in std_all:
#     if [x] > risk:
#         riskier_port.append(x)
#     else:
#         pass

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
std_sp_yearly = sp.std() * (252 ** 0.5)
std_algo_yearly = algo.std() * (252 ** 0.5)
std_whale_yearly = whale.std() * (252 ** 0.5)
print (std_sp_yearly, std_algo_yearly, std_whale_yearly)
# Out:
# SP500 Returns    0.128762
# dtype: float64 Algo 1    0.126801
# Algo 2    0.134401
# dtype: float64 SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# BERKSHIRE HATHAWAY INC         0.203682
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

# Plot the rolling standard deviation
plot1 = merged.rolling(window=21).std().plot(figsize = (20,20))

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
corr = merged.corr()
# Display de correlation matrix
sns.heatmap(corr, vmax=1, vmin=-1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_algo = merged["Algo 1"].cov(merged["SP500 Returns"])
print (covariance_algo)
# Calculate variance of S&P 500
variance = merged["SP500 Returns"].var()
print (variance)
# Computing beta
beta_algo = covariance_algo/variance
print(beta_algo)
# Plot beta trend
rolling_algo_covariance = merged['Algo 1'].rolling(window=30).cov(merged['SP500 Returns'])
rolling_variance = merged['SP500 Returns'].rolling(window=30).var()
rolling_algo_beta = rolling_algo_covariance / rolling_variance
rolling_algo_beta.plot(figsize = (12,12))
# Out:
# -7.500721179231243e-07
# 7.29025248363392e-05
# -0.010288698774246586
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
whale.ewm(halflife = 21).std().plot(figsize = (20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_algo = (algo.mean()/algo.std()) * (252 ** 0.5)
sharpe_sp = (sp.mean()/sp.std()) * (252 ** 0.5)
sharpe_whale = (whale.mean()/whale.std()) * (252 ** 0.5)

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_algo.plot(kind="bar")
sharpe_sp.plot(kind = "bar")
sharpe_whale.plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
"Yes"
# Out:
# 'Yes'

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
cathie = pd.read_csv("stonks/ARKK.csv", parse_dates = True, infer_datetime_format = True)
cathie.drop(cathie.columns.difference(['Close', "Date"]), 1, inplace=True)
cathie.rename(columns={"Date": "Date", "Close": "ARKK"}, inplace = True)
cathie.head()
# Out:
#            Date   ARKK
# 0  Oct 23, 2020  99.18
# 1  Oct 26, 2020  97.20
# 2  Oct 27, 2020  98.63
# 3  Oct 28, 2020  94.75
# 4  Oct 29, 2020  95.99

# %%
# Reading data from 2nd stock
clover = pd.read_csv("stonks/CLOV.csv", parse_dates = True, infer_datetime_format = True)
clover.drop(clover.columns.difference(['Close']), 1, inplace=True)
clover.rename(columns={"Close": "CLOV"}, inplace = True)
clover.head()
# Out:
#     CLOV
# 0  10.20
# 1  10.10
# 2  10.08
# 3   9.99
# 4   9.98

# %%
# Reading data from 3rd stock
wsb = pd.read_csv("stonks/GME.csv", parse_dates = True, infer_datetime_format = True)
wsb.drop(wsb.columns.difference(['Close']), 1, inplace=True)
wsb.rename(columns={"Close": "GME"}, inplace = True)
wsb.head()
# Out:
#      GME
# 0  15.00
# 1  13.45
# 2  12.69
# 3  11.82
# 4  11.73

# %%
# Combine all stocks in a single DataFrame
merged1 = cathie.join((wsb,clover))
merged1
# Out:
#              Date    ARKK     GME   CLOV
# 0    Oct 23, 2020   99.18   15.00  10.20
# 1    Oct 26, 2020   97.20   13.45  10.10
# 2    Oct 27, 2020   98.63   12.69  10.08
# 3    Oct 28, 2020   94.75   11.82   9.99
# 4    Oct 29, 2020   95.99   11.73   9.98
# ..            ...     ...     ...    ...
# 246  Oct 15, 2021  115.80  183.28   7.91
# 247  Oct 18, 2021  117.05  186.02   7.89
# 248  Oct 19, 2021  119.60  186.79   7.92
# 249  Oct 20, 2021  118.70  184.52   7.84
# 250  Oct 21, 2021  119.66  181.71   7.86
#
# [251 rows x 4 columns]

# %%
# Reset Date index
merged1.set_index("Date",inplace = True)

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
pct_change = merged1.pct_change()
# Drop NAs
pct_change.dropna(inplace = True)
# Display sample data
pct_change
# Out:
#                   ARKK       GME      CLOV
# Date
# Oct 26, 2020 -0.019964 -0.103333 -0.009804
# Oct 27, 2020  0.014712 -0.056506 -0.001980
# Oct 28, 2020 -0.039339 -0.068558 -0.008929
# Oct 29, 2020  0.013087 -0.007614 -0.001001
# Oct 30, 2020 -0.054172 -0.107417  0.004008
# ...                ...       ...       ...
# Oct 15, 2021  0.001903 -0.002992 -0.025862
# Oct 18, 2021  0.010794  0.014950 -0.002528
# Oct 19, 2021  0.021786  0.004139  0.003802
# Oct 20, 2021 -0.007525 -0.012153 -0.010101
# Oct 21, 2021  0.008088 -0.015229  0.002551
#
# [250 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3,1/3,1/3]

# Calculate portfolio return
port_daily = pct_change.dot(weights)
# Display sample data
port_daily
# Out:
# Date
# Oct 26, 2020   -0.044367
# Oct 27, 2020   -0.014591
# Oct 28, 2020   -0.038942
# Oct 29, 2020    0.001491
# Oct 30, 2020   -0.052527
#                   ...
# Oct 15, 2021   -0.008984
# Oct 18, 2021    0.007739
# Oct 19, 2021    0.009909
# Oct 20, 2021   -0.009926
# Oct 21, 2021   -0.001530
# Length: 250, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
Custom_weighted = port_daily.to_frame(name="Custom")
Custom_weighted
# Out:
#                 Custom
# Date
# Oct 26, 2020 -0.044367
# Oct 27, 2020 -0.014591
# Oct 28, 2020 -0.038942
# Oct 29, 2020  0.001491
# Oct 30, 2020 -0.052527
# ...                ...
# Oct 15, 2021 -0.008984
# Oct 18, 2021  0.007739
# Oct 19, 2021  0.009909
# Oct 20, 2021 -0.009926
# Oct 21, 2021 -0.001530
#
# [250 rows x 1 columns]

# %%
# Join your returns DataFrame to the original returns DataFrame

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
#merged_all.dropna()

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
cus_annual_std = pct_change.std() * (252 ** 0.5)
cus_annual_std
# Out:
# ARKK    0.387920
# GME     2.721787
# CLOV    1.281592
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
pct_change.rolling(window = 21).std().plot(figsize = (20,20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_c = pct_change.corr()
correlation_c.plot(figsize = (8,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
cov = Custom_weighted["Custom"].cov(sp['SP500 Returns'])
cov
# Out:
# nan

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
Custom_std = Custom_weighted.std()
sharpe_ratios_custom = (Custom_weighted.mean() * 252) / (Custom_std * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_custom.plot(kind="bar",title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
merged_std = merged.std()
sharpe_ratios_merged = (merged.mean() * 252) / (merged_std * np.sqrt(252))
sharpe_ratios_merged.plot(kind="bar",title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# Custom Porfolio outperforms all other portfolios.
